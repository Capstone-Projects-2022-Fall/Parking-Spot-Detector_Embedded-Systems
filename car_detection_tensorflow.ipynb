# %%
import tensorflow as tf

# %%
from matplotlib import pyplot as plt

# %%
# !pip install pixellib
# Out:
# Collecting pixellib
#   Downloading pixellib-0.7.1-py3-none-any.whl (430 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 430.3/430.3 kB 3.6 MB/s eta 0:00:00a 0:00:01
# Collecting tabulate
#   Downloading tabulate-0.9.0-py3-none-any.whl (35 kB)
# Collecting pydot
#   Downloading pydot-1.4.2-py2.py3-none-any.whl (21 kB)
# Collecting fvcore
#   Downloading fvcore-0.1.5.post20220512.tar.gz (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.1/50.1 kB 1.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting Cython
#   Downloading Cython-0.29.32-py2.py3-none-any.whl (986 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 986.3/986.3 kB 13.0 MB/s eta 0:00:00a 0:00:01
# Collecting future
#   Downloading future-0.18.2.tar.gz (829 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 829.2/829.2 kB 14.0 MB/s eta 0:00:0000:01
#   Preparing metadata (setup.py) ... done
# Collecting hydra-core
#   Downloading hydra_core-1.2.0-py3-none-any.whl (151 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.1/151.1 kB 4.8 MB/s eta 0:00:00
# Collecting matplotlib
#   Downloading matplotlib-3.6.2-cp38-cp38-macosx_10_12_x86_64.whl (7.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.3/7.3 MB 22.4 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: termcolor in /Users/hasib/Documents/College/tftest/lib/python3.8/site-packages (from pixellib) (1.1.0)
# Collecting black
#   Downloading black-22.10.0-1fixedarch-cp38-cp38-macosx_10_16_x86_64.whl (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 12.3 MB/s eta 0:00:0000:01
# Collecting dataclasses
#   Downloading dataclasses-0.6-py3-none-any.whl (14 kB)
# Collecting iopath
#   Downloading iopath-0.1.10.tar.gz (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 1.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting imantics
#   Downloading imantics-0.1.12.tar.gz (13 kB)
#   Preparing metadata (setup.py) ... done
# Collecting scikit-image
#   Downloading scikit_image-0.19.3-cp38-cp38-macosx_10_13_x86_64.whl (13.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.2/13.2 MB 30.2 MB/s eta 0:00:0000:0100:01
# Collecting cloudpickle
#   Downloading cloudpickle-2.2.0-py3-none-any.whl (25 kB)
# Collecting tqdm
#   Downloading tqdm-4.64.1-py2.py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 kB 3.1 MB/s eta 0:00:00
# Collecting imgaug
#   Downloading imgaug-0.4.0-py2.py3-none-any.whl (948 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 948.0/948.0 kB 27.6 MB/s eta 0:00:00
# Collecting opencv-python
#   Using cached opencv_python-4.6.0.66-cp36-abi3-macosx_10_15_x86_64.whl (46.4 MB)
# Collecting pillow
#   Using cached Pillow-9.3.0-cp38-cp38-macosx_10_10_x86_64.whl (3.3 MB)
# Collecting pyQt5
#   Downloading PyQt5-5.15.7-cp37-abi3-macosx_10_13_x86_64.whl (7.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 33.5 MB/s eta 0:00:0000:0100:01
# Collecting yacs
#   Downloading yacs-0.1.8-py3-none-any.whl (14 kB)
# Collecting omegaconf
#   Downloading omegaconf-2.2.3-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.3/79.3 kB 2.7 MB/s eta 0:00:00
# Collecting labelme2coco
#   Downloading labelme2coco-0.2.1-py3-none-any.whl (18 kB)
# Collecting typing-extensions>=3.10.0.0
#   Using cached typing_extensions-4.4.0-py3-none-any.whl (26 kB)
# Collecting pathspec>=0.9.0
#   Downloading pathspec-0.10.1-py3-none-any.whl (27 kB)
# Collecting tomli>=1.1.0
#   Downloading tomli-2.0.1-py3-none-any.whl (12 kB)
# Collecting click>=8.0.0
#   Downloading click-8.1.3-py3-none-any.whl (96 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.6/96.6 kB 4.1 MB/s eta 0:00:00
# Requirement already satisfied: platformdirs>=2 in /Users/hasib/Documents/College/tftest/lib/python3.8/site-packages (from black->pixellib) (2.5.3)
# Collecting mypy-extensions>=0.4.3
#   Downloading mypy_extensions-0.4.3-py2.py3-none-any.whl (4.5 kB)
# Requirement already satisfied: numpy in /Users/hasib/Documents/College/tftest/lib/python3.8/site-packages (from fvcore->pixellib) (1.19.5)
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp38-cp38-macosx_10_9_x86_64.whl (192 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 192.2/192.2 kB 7.2 MB/s eta 0:00:00
# Collecting portalocker
#   Downloading portalocker-2.6.0-py2.py3-none-any.whl (15 kB)
# Collecting antlr4-python3-runtime==4.9.*
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 5.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: packaging in /Users/hasib/Documents/College/tftest/lib/python3.8/site-packages (from hydra-core->pixellib) (21.3)
# Requirement already satisfied: importlib-resources in /Users/hasib/Documents/College/tftest/lib/python3.8/site-packages (from hydra-core->pixellib) (5.10.0)
# Collecting lxml
#   Downloading lxml-4.9.1-cp38-cp38-macosx_10_15_x86_64.whl (4.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 32.5 MB/s eta 0:00:0000:0100:01
# Collecting xmljson
#   Downloading xmljson-0.2.1-py2.py3-none-any.whl (10 kB)
# Collecting imageio
#   Downloading imageio-2.22.4-py3-none-any.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 32.7 MB/s eta 0:00:0000:0100:01
# Collecting scipy
#   Downloading scipy-1.9.3-cp38-cp38-macosx_10_9_x86_64.whl (34.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.2/34.2 MB 33.2 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: six in /Users/hasib/Documents/College/tftest/lib/python3.8/site-packages (from imgaug->pixellib) (1.15.0)
# Collecting Shapely
#   Downloading Shapely-1.8.5.post1-cp38-cp38-macosx_10_9_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 29.8 MB/s eta 0:00:0000:01
# Collecting tifffile>=2019.7.26
#   Downloading tifffile-2022.10.10-py3-none-any.whl (210 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 210.3/210.3 kB 9.0 MB/s eta 0:00:00
# Collecting networkx>=2.2
#   Downloading networkx-2.8.8-py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 37.7 MB/s eta 0:00:0000:01
# Collecting PyWavelets>=1.1.1
#   Downloading PyWavelets-1.4.1-cp38-cp38-macosx_10_13_x86_64.whl (4.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 41.6 MB/s eta 0:00:0000:0100:01
# Collecting sahi>=0.8.19
#   Downloading sahi-0.11.1-py3-none-any.whl (99 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.0/99.0 kB 4.4 MB/s eta 0:00:00
# Requirement already satisfied: jsonschema>=2.6.0 in /Users/hasib/Documents/College/tftest/lib/python3.8/site-packages (from labelme2coco->pixellib) (4.17.0)
# Collecting fonttools>=4.22.0
#   Using cached fonttools-4.38.0-py3-none-any.whl (965 kB)
# Collecting contourpy>=1.0.1
#   Using cached contourpy-1.0.6-cp38-cp38-macosx_10_9_x86_64.whl (240 kB)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/hasib/Documents/College/tftest/lib/python3.8/site-packages (from matplotlib->pixellib) (3.0.9)
# Collecting kiwisolver>=1.0.1
#   Using cached kiwisolver-1.4.4-cp38-cp38-macosx_10_9_x86_64.whl (65 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/hasib/Documents/College/tftest/lib/python3.8/site-packages (from matplotlib->pixellib) (2.8.2)
# Collecting cycler>=0.10
#   Using cached cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Collecting PyQt5-sip<13,>=12.11
#   Downloading PyQt5_sip-12.11.0-cp38-cp38-macosx_10_9_x86_64.whl (84 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.8/84.8 kB 3.4 MB/s eta 0:00:00
# Collecting PyQt5-Qt5>=5.15.0
#   Downloading PyQt5_Qt5-5.15.2-py3-none-macosx_10_13_intel.whl (40.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.5/40.5 MB 34.9 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Users/hasib/Documents/College/tftest/lib/python3.8/site-packages (from jsonschema>=2.6.0->labelme2coco->pixellib) (0.19.2)
# Requirement already satisfied: attrs>=17.4.0 in /Users/hasib/Documents/College/tftest/lib/python3.8/site-packages (from jsonschema>=2.6.0->labelme2coco->pixellib) (22.1.0)
# Requirement already satisfied: pkgutil-resolve-name>=1.3.10 in /Users/hasib/Documents/College/tftest/lib/python3.8/site-packages (from jsonschema>=2.6.0->labelme2coco->pixellib) (1.3.10)
# Requirement already satisfied: zipp>=3.1.0 in /Users/hasib/Documents/College/tftest/lib/python3.8/site-packages (from importlib-resources->hydra-core->pixellib) (3.10.0)
# Collecting click>=8.0.0
#   Downloading click-8.0.4-py3-none-any.whl (97 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.5/97.5 kB 3.0 MB/s eta 0:00:00
# Collecting terminaltables
#   Downloading terminaltables-3.1.10-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: requests in /Users/hasib/Documents/College/tftest/lib/python3.8/site-packages (from sahi>=0.8.19->labelme2coco->pixellib) (2.28.1)
# Collecting fire
#   Downloading fire-0.4.0.tar.gz (87 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.7/87.7 kB 3.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting pybboxes==0.1.5
#   Downloading pybboxes-0.1.5-py3-none-any.whl (24 kB)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/hasib/Documents/College/tftest/lib/python3.8/site-packages (from requests->sahi>=0.8.19->labelme2coco->pixellib) (1.26.12)
# Requirement already satisfied: idna<4,>=2.5 in /Users/hasib/Documents/College/tftest/lib/python3.8/site-packages (from requests->sahi>=0.8.19->labelme2coco->pixellib) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/hasib/Documents/College/tftest/lib/python3.8/site-packages (from requests->sahi>=0.8.19->labelme2coco->pixellib) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/hasib/Documents/College/tftest/lib/python3.8/site-packages (from requests->sahi>=0.8.19->labelme2coco->pixellib) (2022.9.24)
# Building wheels for collected packages: future, fvcore, iopath, antlr4-python3-runtime, imantics, fire
#   Building wheel for future (setup.py) ... done
#   Created wheel for future: filename=future-0.18.2-py3-none-any.whl size=491059 sha256=f04c19d867c95da9aebfbf96c3db143a3f4251d096a851eb68d2bc893d9d564a
#   Stored in directory: /Users/hasib/Library/Caches/pip/wheels/01/49/0c/4e0a697824c7bd6516afb22e1af9d51427ccd36c74b05a297e
#   Building wheel for fvcore (setup.py) ... done
#   Created wheel for fvcore: filename=fvcore-0.1.5.post20220512-py3-none-any.whl size=61288 sha256=8ae0d206a55f641c42cb078f1380f6e6ed896a2cc6054867588509729070e9c4
#   Stored in directory: /Users/hasib/Library/Caches/pip/wheels/c0/da/76/70c9274744d8f5ffa2fe7ea4b79daf1aa127ab8e57a2c2ca1e
#   Building wheel for iopath (setup.py) ... done
#   Created wheel for iopath: filename=iopath-0.1.10-py3-none-any.whl size=31541 sha256=0848cabd0acb5845fa369d2cfbfdf9fcd0c930f38f55926d79ed8774d1a2e728
#   Stored in directory: /Users/hasib/Library/Caches/pip/wheels/85/e6/c8/4a67ea2cd453fd2e02c616b615fe8655ae67246c8e669bd464
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144573 sha256=bf3bbd4163f2f03cd6b692f02602333eb3549f006cc2a3c1ee1f50e86aaaa3f1
#   Stored in directory: /Users/hasib/Library/Caches/pip/wheels/11/20/e3/33bfd201db65084a9bb7ec0fd4040c2a7b59bb155698396a7c
#   Building wheel for imantics (setup.py) ... done
#   Created wheel for imantics: filename=imantics-0.1.12-py3-none-any.whl size=16033 sha256=33e02b20acde8a08f9d287cac7d710bf40a239a20c5200b5f551cbac4c93d27c
#   Stored in directory: /Users/hasib/Library/Caches/pip/wheels/d2/f2/79/b7b6d2648ddaa87d7142613aa9963f1b8c44041242e497bb3e
#   Building wheel for fire (setup.py) ... done
#   Created wheel for fire: filename=fire-0.4.0-py2.py3-none-any.whl size=115928 sha256=f8ca2954bbcf2960270438b0037299361ee5413e986846ca8aadfe5b19656104
#   Stored in directory: /Users/hasib/Library/Caches/pip/wheels/61/05/8d/5951e074fe660f634ca0a3402fa9903d9f772014fdb0e593dd
# Successfully built future fvcore iopath antlr4-python3-runtime imantics fire
# Installing collected packages: xmljson, PyQt5-Qt5, mypy-extensions, dataclasses, antlr4-python3-runtime, typing-extensions, tqdm, tomli, tifffile, terminaltables, tabulate, Shapely, scipy, pyyaml, PyWavelets, PyQt5-sip, pydot, pybboxes, portalocker, pillow, pathspec, opencv-python, networkx, lxml, kiwisolver, future, fonttools, fire, Cython, cycler, contourpy, cloudpickle, click, yacs, sahi, pyQt5, omegaconf, matplotlib, iopath, imantics, imageio, black, scikit-image, labelme2coco, hydra-core, fvcore, imgaug, pixellib
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 3.7.4.3
#     Uninstalling typing-extensions-3.7.4.3:
#       Successfully uninstalled typing-extensions-3.7.4.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.4.1 requires typing-extensions~=3.7.4, but you have typing-extensions 4.4.0 which is incompatible.
# Successfully installed Cython-0.29.32 PyQt5-Qt5-5.15.2 PyQt5-sip-12.11.0 PyWavelets-1.4.1 Shapely-1.8.5.post1 antlr4-python3-runtime-4.9.3 black-22.10.0 click-8.0.4 cloudpickle-2.2.0 contourpy-1.0.6 cycler-0.11.0 dataclasses-0.6 fire-0.4.0 fonttools-4.38.0 future-0.18.2 fvcore-0.1.5.post20220512 hydra-core-1.2.0 imageio-2.22.4 imantics-0.1.12 imgaug-0.4.0 iopath-0.1.10 kiwisolver-1.4.4 labelme2coco-0.2.1 lxml-4.9.1 matplotlib-3.6.2 mypy-extensions-0.4.3 networkx-2.8.8 omegaconf-2.2.3 opencv-python-4.6.0.66 pathspec-0.10.1 pillow-9.3.0 pixellib-0.7.1 portalocker-2.6.0 pyQt5-5.15.7 pybboxes-0.1.5 pydot-1.4.2 pyyaml-6.0 sahi-0.11.1 scikit-image-0.19.3 scipy-1.9.3 tabulate-0.9.0 terminaltables-3.1.10 tifffile-2022.10.10 tomli-2.0.1 tqdm-4.64.1 typing-extensions-4.4.0 xmljson-0.2.1 yacs-0.1.8

# %%
from pixellib.instance import instance_segmentation

# %%
import cv2

# %%
segmentation_model = instance_segmentation()
segmentation_model.load_model('mask_rcnn_coco.h5')
# Out:
# 2022-11-10 19:20:25.175516: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-10 19:20:25.536662: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:196] None of the MLIR optimization passes are enabled (registered 0 passes)

# %%
instance_segmentation??

# %%
segmentation_model.select_target_classes(person=True)
# Out:
# {'BG': 'invalid',
#  'person': 'valid',
#  'bicycle': 'invalid',
#  'car': 'invalid',
#  'motorcycle': 'invalid',
#  'airplane': 'invalid',
#  'bus': 'invalid',
#  'train': 'invalid',
#  'truck': 'invalid',
#  'boat': 'invalid',
#  'traffic light': 'invalid',
#  'fire hydrant': 'invalid',
#  'stop sign': 'invalid',
#  'parking meter': 'invalid',
#  'bench': 'invalid',
#  'bird': 'invalid',
#  'cat': 'invalid',
#  'dog': 'invalid',
#  'horse': 'invalid',
#  'sheep': 'invalid',
#  'cow': 'invalid',
#  'elephant': 'invalid',
#  'bear': 'invalid',
#  'zebra': 'invalid',
#  'giraffe': 'invalid',
#  'backpack': 'invalid',
#  'umbrella': 'invalid',
#  'handbag': 'invalid',
#  'tie': 'invalid',
#  'suitcase': 'invalid',
#  'frisbee': 'invalid',
#  'skis': 'invalid',
#  'snowboard': 'invalid',
#  'sports ball': 'invalid',
#  'kite': 'invalid',
#  'baseball bat': 'invalid',
#  'baseball glove': 'invalid',
#  'skateboard': 'invalid',
#  'surfboard': 'invalid',
#  'tennis racket': 'invalid',
#  'bottle': 'invalid',
#  'wine glass': 'invalid',
#  'cup': 'invalid',
#  'fork': 'invalid',
#  'knife': 'invalid',
#  'spoon': 'invalid',
#  'bowl': 'invalid',
#  'banana': 'invalid',
#  'apple': 'invalid',
#  'sandwich': 'invalid',
#  'orange': 'invalid',
#  'broccoli': 'invalid',
#  'carrot': 'invalid',
#  'hot dog': 'invalid',
#  'pizza': 'invalid',
#  'donut': 'invalid',
#  'cake': 'invalid',
#  'chair': 'invalid',
#  'couch': 'invalid',
#  'potted plant': 'invalid',
#  'bed': 'invalid',
#  'dining table': 'invalid',
#  'toilet': 'invalid',
#  'tv': 'invalid',
#  'laptop': 'invalid',
#  'mouse': 'invalid',
#  'remote': 'invalid',
#  'keyboard': 'invalid',
#  'cell phone': 'invalid',
#  'microwave': 'invalid',
#  'oven': 'invalid',
#  'toaster': 'invalid',
#  'sink': 'invalid',
#  'refrigerator': 'invalid',
#  'book': 'invalid',
#  'clock': 'invalid',
#  'vase': 'invalid',
#  'scissors': 'invalid',
#  'teddy bear': 'invalid',
#  'hair dryer': 'invalid',
#  'toothbrush': 'invalid'}

# %%
img = cv2.imread(filename="assets/img1.JPG")
plt.imshow(img)

# %%
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)

# %%
res = segmentation_model.segmentFrame(img, show_bboxes=True)
img_seg=res[1]
plt.imshow(img_seg)

# %%
numofobj= len(res[0]['rois'])
print(numofobj)
# Out:
# 8

# %%
# Out:
# ({'rois': array([[1776,    2, 1900,  383],
#          [1773, 1249, 1891, 1574],
#          [1738, 1582, 1887, 1962],
#          [1736, 2032, 1876, 2379],
#          [1727, 3132, 1872, 3296],
#          [1770, 1126, 1882, 1240],
#          [1761,  372, 1896,  707],
#          [1762, 2438, 1986, 2788]], dtype=int32),
#   'class_ids': array([3, 3, 3, 3, 3, 3, 3, 3], dtype=int32),
#   'scores': array([0.99610054, 0.9943311 , 0.990146  , 0.9787496 , 0.97777873,
#          0.96897316, 0.96477646, 0.93037623], dtype=float32),
#   'masks': array([[[False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False],
#           ...,
#           [False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False]],
#
#          [[False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False],
#           ...,
#           [False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False]],
#
#          [[False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False],
#           ...,
#           [False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False]],
#
#          ...,
#
#          [[False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False],
#           ...,
#           [False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False]],
#
#          [[False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False],
#           ...,
#           [False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False]],
#
#          [[False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False],
#           ...,
#           [False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False]]])},
#  array([[[69, 66, 61],
#          [68, 65, 60],
#          [68, 65, 60],
#          ...,
#          [75, 78, 76],
#          [78, 81, 79],
#          [79, 82, 80]],
#
#         [[68, 65, 60],
#          [67, 64, 59],
#          [67, 64, 59],
#          ...,
#          [76, 79, 77],
#          [77, 80, 78],
#          [77, 80, 78]],
#
#         [[66, 63, 58],
#          [67, 64, 59],
#          [68, 65, 60],
#          ...,
#          [75, 78, 76],
#          [74, 77, 75],
#          [72, 75, 73]],
#
#         ...,
#
#         [[51, 49, 48],
#          [53, 51, 50],
#          [51, 49, 48],
#          ...,
#          [45, 43, 42],
#          [46, 44, 43],
#          [46, 44, 43]],
#
#         [[55, 53, 52],
#          [54, 52, 51],
#          [58, 56, 55],
#          ...,
#          [45, 43, 42],
#          [45, 43, 42],
#          [44, 42, 41]],
#
#         [[57, 55, 54],
#          [47, 45, 44],
#          [52, 50, 49],
#          ...,
#          [46, 44, 43],
#          [45, 43, 42],
#          [43, 41, 40]]], dtype=uint8))
